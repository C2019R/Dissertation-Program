# %%
#Import pandas and dataset
import pandas as pd
df = pd.read_csv("Pre-Processed Dataset.csv")

#Select predictor columns
cols = ['CourseViewed', 'ReasonForStudy', 'LearnerType', 'StudyHours', 'PreviousEducation', 'AgeRange']
data = df[cols]
#Assign the SubjectArea column as target
target = df['SubjectArea']

#Import the necessary module
from sklearn.model_selection import train_test_split
#Split data set into train and test sets data_train, data_test, target_train, 
target_test = train_test_split(data,target, test_size = 0.30, random_state = 10)
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size= 0.30, random_state = 10)

#Import the necessary module
from sklearn.svm import SVC
#Create an object of the type SVC
svc_model = SVC(random_state=0, class_weight='balanced')
#Train the algorithm on training data and predict using the testing data
pred = svc_model.fit(data_train, target_train).predict(data_test)

#Import Pickle module
import pickle
#Save model
filename='F:/Dissertation/Transcripts/Trained_model.sav'
pickle.dump(svc_model, open(filename, 'wb'))
load_lr_model =pickle.load(open(filename, 'rb'))
#Load model
load_lr_model =pickle.load(open('F:/Dissertation/Transcripts/Trained_model.sav', 'rb'))

# %%
#Define module
def interactive_module ():
    load_lr_model =pickle.load(open('F:/Dissertation/Transcripts/Trained_model.sav', 'rb'))
    #Obtain values for model prediction 
    while True:
        try:
            #Provide user information for question 1
            print("Question 1")
            print("\n")
            print("Input 0 for No ")
            print("Input 1 for Yes ")
            print("\n") 
            #Obtain response for question 1
            CourseViewed=str(input("Have you viewed a specific course? "))
            print("\n")
            #Handle exception of invalid entry
            while CourseViewed != "0" and CourseViewed != "1":
                CourseViewed=str(input("Invalid entry, please enter 0 or 1! "))
                print("\n")
            #Allow user to input new values
            if CourseViewed=="0" and CourseViewed=="1":
                continue
                
            #Provide user information for question 2
            print("\n")
            print("\n")
            print("Question 2")
            print("\n")
            print("Input 1 for 'I want to progress my career' ")
            print("Input 2 for 'I want to be part of a student community' ")
            print("Input 3 for 'I want to specialise and pursue a subject of interest' ")
            print("Input 4 for 'I want to challenge myself and experience university study' ")
            print("\n") 
            #Obtain response for question 2
            ReasonForStudy=str(input("Which statement best describes your reason for applying to a university course? "))
            print("\n") 
            #Handle exception of invalid entry
            while ReasonForStudy != "1" and ReasonForStudy != "2" and ReasonForStudy != "3" and ReasonForStudy != "4":
                ReasonForStudy=str(input("Invalid entry, please enter 1, 2, 3 or 4! "))
                print("\n")
            #Allow user to input new values
            if ReasonForStudy=="1" and ReasonForStudy=="2" and ReasonForStudy=="3" and ReasonForStudy=="4":
                continue
            
            #Provide user information for question 3
            print("\n")
            print("\n")
            print("Question 3")
            print("\n")
            print("Input 1 for 'My learning style is to actively participate in group work' ")
            print("Input 2 for 'My learning style is to actively take the lead in group work' ")
            print("Input 3 for 'My learning style is to participate when required' ")
            print("Input 4 for 'My learning style is to watch and observe others' ")
            print("Input 5 for 'My learning style is to leave work for others when I don’t understand it' ")
            print("Input 6 for 'My learning style is to work when asked by other group members' ")
            print("\n") 
            #Obtain response for question 3
            LearnerType=str(input("Which statement best describes your learning style? "))
            print("\n") 
            #Handle exception of invalid entry
            while LearnerType != "1" and LearnerType != "2" and LearnerType != "3" and LearnerType != "4" \
            and LearnerType != "5" and LearnerType != "6":
                LearnerType=str(input("Invalid entry, please enter 1, 2, 3, 4, 5 or 6! "))
                print("\n")
            #Allow user to input new values
            if LearnerType=="1" and LearnerType=="2" and LearnerType=="3" and LearnerType=="4" \
            and LearnerType=="5" and LearnerType=="6":
                continue
            
            #Provide user information for question 4
            print("\n")
            print("\n")
            print("Question 4")
            print("\n")
            print("Input 1 for 'I am pursuing university mainly for the student life' ")
            print("Input 2 for 'I expect to do the absolute minimum to complete the work' ")
            print("Input 3 for 'I expect to balance studying around a part-time job' ")
            print("Input 4 for 'I expect to commit time for study outside of university hours' ")
            print("Input 5 for 'I expect to undertake a high degree of outside reading to complete assignments' ")
            print("Input 6 for 'I expect to excel at university and push the boundaries to achieve high grades' ")
            print("\n") 
            #Obtain response for question 4
            StudyHours=str(input("Which statement best describes your commitment to study? "))
            print("\n")
            #Handle exception of invalid entry
            while StudyHours != "1" and StudyHours != "2" and StudyHours != "3" and StudyHours != "4" \
            and StudyHours != "5" and StudyHours != "6":
                StudyHours=str(input("Invalid entry, please enter 1, 2, 3, 4, 5 or 6! "))
                print("\n")
            #Allow user to input new values
            if StudyHours=="1" and StudyHours=="2" and StudyHours=="3" and StudyHours=="4" \
            and StudyHours=="5" and StudyHours=="6":
                continue 
            
            #Provide user information for question 5
            print("\n")
            print("\n")
            print("Question 5")
            print("\n")
            print("Input 1 for Foundation ")
            print("Input 2 for Undergraduate ")
            print("Input 3 for Master’s ")
            print("Input 4 for PhD ")
            print("\n") 
            #Obtain response for question 5
            PreviousEducation=str(input("What is your current level of study? "))
            print("\n")
            #Handle exception of invalid entry
            while PreviousEducation != "1" and PreviousEducation != "2" and PreviousEducation != "3" \
            and PreviousEducation != "4":
                PreviousEducation=str(input("Invalid entry, please enter 1, 2, 3 or 4! "))
                print("\n")
            #Allow user to input new values
            if PreviousEducation=="1" and PreviousEducation=="2" and PreviousEducation=="3" and PreviousEducation=="4":
                continue
            
            #Provide user information for question 6
            print("\n")
            print("\n")
            print("Question 6")
            print("\n")
            print("Input 1 for 19-34 ")
            print("Input 2 for 35-54 ")
            print("input 3 for 55+ ")
            print("\n") 
            #Obtain response for question 6
            AgeRange=str(input("What is your age range? "))
            print("\n")
            #Handle exception of invalid entry
            while AgeRange != "1" and AgeRange != "2" and AgeRange != "3":
                AgeRange=str(input("Invalid entry, please enter 1, 2 or 3! "))
                print("\n")
            #Allow user to input new values
            if AgeRange=="1" and AgeRange=="2" and AgeRange=="3":
                continue
    
            print("\n")
            print("\n")
            print("The predicted subject discipline is: ")
            print("\n")
            print(df.SubjectArea[svc_model.predict([[CourseViewed, ReasonForStudy, LearnerType, \
                                                     StudyHours, PreviousEducation, AgeRange]])])
            print("\n")
            
            #Provide course list
            print("\n")
            print("\n")
            print("List of course disciplines:")
            print("\n")
            print("Input 1 for 'Mathematics & Statistics' ")
            print("Input 2 for 'Professions and Applied Sciences' ")
            print("Input 3 for 'Medical Pre-Medical' ")
            print("Input 4 for 'Education' ")
            print("Input 5 for 'Interdisciplinary & Other' ")
            print("Input 6 for 'Social Sciences' ")
            print("Input 7 for 'Business and Management' ")
            print("Input 8 for 'Humanities' ")
            print("Input 9 for 'Computer Science' ")
            print("Input 10 for 'Physical Sciences' ")
            print("\n") 
            #Obtain response for course discipline question
            SubjectOutput=str(input("Which subject discpline was predicted? "))
            print("\n") 
            #Handle exception of invalid entry
            while SubjectOutput != "1" and SubjectOutput != "2" and SubjectOutput != "3" and SubjectOutput != "4" \
            and SubjectOutput != "5" and SubjectOutput != "6" and SubjectOutput != "7" and SubjectOutput != "8" \
            and SubjectOutput != "9" and SubjectOutput != "10":
                SubjectOutput=str(input("Invalid entry, please enter 1, 2, 3, 4, 5, 6, 7, 8, 9 or 10! "))
                print("\n")
            #Allow user to input new values
            if SubjectOutput=="1" and SubjectOutput=="2" and SubjectOutput=="3" and SubjectOutput=="4" \
            and SubjectOutput=="5" and SubjectOutput=="6" and SubjectOutput=="7" and SubjectOutput=="8" \
            and SubjectOutput=="9" and SubjectOutput=="10":
                continue
                
            print("Here are a sample of courses currently offered by clearing:")
            print("\n")
            if SubjectOutput== "1":
                print("Mathematics", "Mathematics with Education and Qualified Teacher Status", \
                      "Mathematics with Foundation Year", "Accounting and Economics", "Finance and Economics", sep = "\n")
            if SubjectOutput== "2":
                print("Environmental Science", "Biosciences and Chemistry", "Science with Education and Qualified Teacher Status", "Chemistry", "Chemistry with Foundation Year", sep = "\n")
            if SubjectOutput== "3":
                print("Biomedical Science", "Biology with Foundation Year", "Biology", "Human Biology", \
                      "Human Biology with Foundation Year", sep = "\n")
            if SubjectOutput== "4":
                print("Education Studies", "Primary Education (5-11) with Qualified Teacher Status", \
                      "Education and Learning Support", "Early Years and Primary Education (3-7) with Qualified Teacher Status", \
                      "Education and Learning Support (1 year top-up)", sep = "\n")
            if SubjectOutput== "5":
                print("Physical Education and School Sport", "Sport and Exercise Technology", \
                      "Sports Journalism", "Sport Business Management", "Sports Journalism with Foundation Year", sep = "\n")
            if SubjectOutput== "6":
                print("Applied Social Science", "Social Work", "Education with Psychology and Counselling", \
                      "Criminology and Sociology", "Psychology", sep = "\n")
            if SubjectOutput== "7":
                print("Business Economics", "Business Analytics", "Business and Management", "Business Studies", \
                      "Business and Enterprise Management", "Business and Information and Communications Technology", sep = "\n")
            if SubjectOutput== "8":
                print("Geography", "Human Geography", "History", "Languages with Tourism", \
                      "Languages with Teaching English to Speakers of Other Languages", \
                      "Languages with International Business", sep = "\n")
            if SubjectOutput== "9":
                print("Computer Science", "Computer Science for Games", "Information Technology with Business Studies", \
                      "Software Engineering", "Computing", "Computing and IT", sep = "\n")
            if SubjectOutput== "10":
                print("Physics", "Physics with Foundation Year", "Automotive Engineering", "Mechanical Engineering", \
                      "Electrical and Electronic Engineering", sep = "\n")
            else:
                print("\n")
                  
            print("\n")
            #Provide option to restart program
            print("Would you like to restart the program? ")
            print("\n")
            #Prompt the user for a response
            restart=str(input("Please enter yes or no: "))
            print("\n")
            #Handle exception of invalid entry
            while restart != "yes" and restart != "no":
                restart=str(input("Invalid entry, please enter yes or no! "))
                print("\n")
            #Allow user to input new values
            if restart=="yes":
                continue   
            #Allow user to exit the program
            elif restart=="no":
                #Close program
                print("Thank you and have a great day!")
                break
                print("\n")
        #Handle exception of invalid entry
        except ValueError:
                CourseViewed=str(input("Invalid entry, please enter 0 or 1! "))
        except ValueError:                
                ReasonForStudy=str(input("Invalid entry, please enter 1, 2, 3 or 4! "))
        except ValueError:
                LearnerType=str(input("Invalid entry, please enter 1, 2, 3, 4, 5 or 6! "))
        except ValueError:
                StudyHours=str(input("Invalid entry, please enter 1, 2, 3, 4, 5 or 6! "))
        except ValueError:
                PreviousEducation=str(input("Invalid entry, please enter 1, 2, 3 or 4! "))
        except ValueError:
                AgeRange=str(input("Invalid entry, please enter 1, 2 or 3! "))
        except ValueError:
                SubjectOutput=str(input("Invalid entry, please enter 1, 2, 3, 4, 5, 6, 7, 8, 9 or 10! "))
                print("\n")

# %%
interactive_module()
